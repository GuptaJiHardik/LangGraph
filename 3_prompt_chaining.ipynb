# %%
from langgraph.graph import StateGraph,START, END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv

# %%
model = ChatGroq(model = "openai/gpt-oss-20b")

# %%
class BlogState(TypedDict):
    title: str
    content: str
    outline:str

# %%
def create_outline(state: BlogState) -> BlogState:
    title = state['title']

    prompt = f"Generate a detailed outline for a blog of the topic {title}"
    outline = model.invoke(prompt).content

    state['outline'] = outline
    return state

# %%
def create_blog(state: BlogState) -> BlogState:
    title = state['title']

    outline = state['outline']
    prompt = f"Write a detailed blog of the tile - {title} using the following outline\n {outline}"

    content = model.invoke(prompt).content
    state['content'] = content
    return state

# %%
graph = StateGraph(BlogState)

graph.add_node("create_outline", create_outline)
graph.add_node("create_blog", create_blog)

graph.add_edge(START, "create_outline")
graph.add_edge("create_outline", "create_blog")
graph.add_edge("create_blog", END)

workflow = graph.compile()

# %%
initial_state = {'title':'Rise of AI'}
final_state = workflow.invoke(initial_state)
print(final_state)
# Out:
# {'title': 'Rise of AI', 'content': '# The Rise of AI: From Turing’s Dream to Tomorrow’s Reality  \n\n*By [Your Name] – AI Enthusiast & Tech Writer*  \n\n---\n\n## 1. Hook & Hook Question  \n\n> **Opening Anecdote:**  \n> Imagine a world where your coffee machine predicts the exact amount of milk you’ll need, the next song you’ll love, and the medical diagnosis you’ll need before you even feel a symptom.  \n\n> **Hook Question:**  \n> *What if the next decade will be defined not by the machines we build, but by the intelligence we embed inside them?*  \n\n---\n\n## 2. Introduction  \n\n### What Is AI?  \nArtificial Intelligence (AI) is the simulation of human intelligence processes by machines—learning, reasoning, perception, and problem‑solving. Think of it as a toolbox that lets computers “think” in ways that were once the exclusive domain of humans.\n\n### Why It Matters  \nFrom automating mundane tasks to discovering new drugs, AI is reshaping every industry. It’s the engine behind the recommendation engines that keep us scrolling, the diagnostic tools that save lives, and the autonomous vehicles that promise safer roads.  \n\n### Thesis Statement  \nThis blog will chart AI’s journey from a philosophical curiosity to a global economic powerhouse. We’ll explore its historical milestones, core technologies, everyday impact, societal challenges, governance debates, economic dynamics, and, finally, where we’re headed in 2030 and beyond.\n\n---\n\n## 3. Historical Timeline: From Myth to Machine  \n\n| Era | Milestones | Key Figures | Technological Breakthrough |\n|-----|------------|-------------|----------------------------|\n| **Early 1900s** | Conceptual foundations (e.g., Alan Turing’s “Computing Machinery and Intelligence”) | Alan Turing | Turing Test |\n| **1950s–1960s** | Dartmouth Conference; first AI programs (e.g., Logic Theorist, ELIZA) | John McCarthy, Marvin Minsky | Symbolic AI, rule‑based systems |\n| **1970s–1980s** | Expert systems (MYCIN, XCON) | Edward Feigenbaum | Knowledge representation, inference engines |\n| **1990s** | First AI winter; resurgence with machine learning | Geoffrey Hinton, Yann LeCun | Neural network revival |\n| **2000s** | Big Data, GPU acceleration | Andrew Ng | Deep learning, convolutional nets |\n| **2010s** | AlphaGo, GPT‑2, BERT | Demis Hassabis, Sam Altman | Reinforcement learning, transformer models |\n| **2020s** | Large language models (GPT‑4, Claude), multimodal AI | OpenAI, Anthropic, Meta | Scale‑up, multimodality, democratization |\n\n> **Tip:** Use a visual timeline infographic to help readers quickly grasp the evolution.  \n\n---\n\n## 4. Core Technologies Underpinning the Rise  \n\n### 4.1 Machine Learning (ML)  \n- **Supervised**: learning from labeled data.  \n- **Unsupervised**: discovering patterns without labels.  \n- **Semi‑supervised**: combining both to reduce annotation costs.  \n- **Feature engineering vs. representation learning**: the shift from hand‑crafted features to end‑to‑end learned representations.\n\n### 4.2 Deep Learning (DL)  \n- **CNNs**: revolutionized computer vision.  \n- **RNNs & LSTMs**: early sequence models.  \n- **Transformers**: the backbone of modern NLP and multimodal AI.  \n\n### 4.3 Reinforcement Learning (RL)  \n- **Policy gradients, Q‑learning, actor‑critic**: learning through interaction.  \n- **Applications**: games (AlphaGo), robotics, autonomous vehicles.  \n\n### 4.4 Natural Language Processing (NLP)  \n- **Embeddings**: word2vec, GloVe.  \n- **Transformers**: BERT, GPT, T5.  \n- **Large‑scale pre‑training**: scaling up to billions of parameters.  \n\n### 4.5 Computer Vision (CV)  \n- **Object detection**: YOLO, Faster R‑CNN.  \n- **Segmentation**: U‑Net, Mask R‑CNN.  \n- **Generative models**: GANs, Diffusion models.  \n\n### 4.6 Edge AI & TinyML  \n- **On‑device inference**: TensorFlow Lite, PyTorch Mobile.  \n- **Low‑power, real‑time applications**: wearables, IoT sensors.  \n\n### 4.7 AI Platforms & Frameworks  \n- **TensorFlo ...

# %%
final_state['content']
# Out:
# '# The Rise of AI: From Turing’s Dream to Tomorrow’s Reality  \n\n*By [Your Name] – AI Enthusiast & Tech Writer*  \n\n---\n\n## 1. Hook & Hook Question  \n\n> **Opening Anecdote:**  \n> Imagine a world where your coffee machine predicts the exact amount of milk you’ll need, the next song you’ll love, and the medical diagnosis you’ll need before you even feel a symptom.  \n\n> **Hook Question:**  \n> *What if the next decade will be defined not by the machines we build, but by the intelligence we embed inside them?*  \n\n---\n\n## 2. Introduction  \n\n### What Is AI?  \nArtificial Intelligence (AI) is the simulation of human intelligence processes by machines—learning, reasoning, perception, and problem‑solving. Think of it as a toolbox that lets computers “think” in ways that were once the exclusive domain of humans.\n\n### Why It Matters  \nFrom automating mundane tasks to discovering new drugs, AI is reshaping every industry. It’s the engine behind the recommendation engines that keep us scrolling, the diagnostic tools that save lives, and the autonomous vehicles that promise safer roads.  \n\n### Thesis Statement  \nThis blog will chart AI’s journey from a philosophical curiosity to a global economic powerhouse. We’ll explore its historical milestones, core technologies, everyday impact, societal challenges, governance debates, economic dynamics, and, finally, where we’re headed in 2030 and beyond.\n\n---\n\n## 3. Historical Timeline: From Myth to Machine  \n\n| Era | Milestones | Key Figures | Technological Breakthrough |\n|-----|------------|-------------|----------------------------|\n| **Early 1900s** | Conceptual foundations (e.g., Alan Turing’s “Computing Machinery and Intelligence”) | Alan Turing | Turing Test |\n| **1950s–1960s** | Dartmouth Conference; first AI programs (e.g., Logic Theorist, ELIZA) | John McCarthy, Marvin Minsky | Symbolic AI, rule‑based systems |\n| **1970s–1980s** | Expert systems (MYCIN, XCON) | Edward Feigenbaum | Knowledge representation, inference engines |\n| **1990s** | First AI winter; resurgence with machine learning | Geoffrey Hinton, Yann LeCun | Neural network revival |\n| **2000s** | Big Data, GPU acceleration | Andrew Ng | Deep learning, convolutional nets |\n| **2010s** | AlphaGo, GPT‑2, BERT | Demis Hassabis, Sam Altman | Reinforcement learning, transformer models |\n| **2020s** | Large language models (GPT‑4, Claude), multimodal AI | OpenAI, Anthropic, Meta | Scale‑up, multimodality, democratization |\n\n> **Tip:** Use a visual timeline infographic to help readers quickly grasp the evolution.  \n\n---\n\n## 4. Core Technologies Underpinning the Rise  \n\n### 4.1 Machine Learning (ML)  \n- **Supervised**: learning from labeled data.  \n- **Unsupervised**: discovering patterns without labels.  \n- **Semi‑supervised**: combining both to reduce annotation costs.  \n- **Feature engineering vs. representation learning**: the shift from hand‑crafted features to end‑to‑end learned representations.\n\n### 4.2 Deep Learning (DL)  \n- **CNNs**: revolutionized computer vision.  \n- **RNNs & LSTMs**: early sequence models.  \n- **Transformers**: the backbone of modern NLP and multimodal AI.  \n\n### 4.3 Reinforcement Learning (RL)  \n- **Policy gradients, Q‑learning, actor‑critic**: learning through interaction.  \n- **Applications**: games (AlphaGo), robotics, autonomous vehicles.  \n\n### 4.4 Natural Language Processing (NLP)  \n- **Embeddings**: word2vec, GloVe.  \n- **Transformers**: BERT, GPT, T5.  \n- **Large‑scale pre‑training**: scaling up to billions of parameters.  \n\n### 4.5 Computer Vision (CV)  \n- **Object detection**: YOLO, Faster R‑CNN.  \n- **Segmentation**: U‑Net, Mask R‑CNN.  \n- **Generative models**: GANs, Diffusion models.  \n\n### 4.6 Edge AI & TinyML  \n- **On‑device inference**: TensorFlow Lite, PyTorch Mobile.  \n- **Low‑power, real‑time applications**: wearables, IoT sensors.  \n\n### 4.7 AI Platforms & Frameworks  \n- **TensorFlow, PyTorch, JAX**: the three pillar ...
